# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2

# %%
# Read in and grayscale the image
image = mpimg.imread('exit-ramp.jpg')
gray = cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(gray,cmap='Greys_r')

# %%
gray.shape
# Out:
# (540, 960)

# %%
gray_rev = np.amax(gray) -1 - gray

# %%
gray_rev
# Out:
# array([[116, 114, 112, ..., 116, 116, 116],
#        [115, 114, 112, ..., 116, 116, 116],
#        [115, 114, 112, ..., 117, 117, 117],
#        ...,
#        [145, 147, 148, ..., 162, 163, 164],
#        [145, 147, 148, ..., 163, 164, 166],
#        [146, 147, 147, ..., 158, 160, 161]], dtype=uint8)

# %%
gray
# Out:
# array([[138, 140, 142, ..., 138, 138, 138],
#        [139, 140, 142, ..., 138, 138, 138],
#        [139, 140, 142, ..., 137, 137, 137],
#        ...,
#        [109, 107, 106, ...,  92,  91,  90],
#        [109, 107, 106, ...,  91,  90,  88],
#        [108, 107, 107, ...,  96,  94,  93]], dtype=uint8)

# %%
#image negative
plt.imshow(gray_rev,cmap='Greys_r')
